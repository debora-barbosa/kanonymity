# %%
from faker import Faker
import pandas as pd
import random
import numpy as np

fake = Faker("pt_BR")

# quantidade de cadastros
n = 1000
alunos = list()

for i in range(n):
    alunos.append([
        fake.first_name() + " " + fake.last_name(), 
        random.randint(14,19), 
        fake.address(),
        fake.random_number(digits=9, fix_len=True), 
        random.choice(["1º", "2º", "3º"]), 
        random.choice(["A", "B"]), 
        round(random.uniform(0,10),2), 
        round(random.uniform(0,10),2), 
        round(random.uniform(0,10),2), 
        round(random.uniform(0,10),2), 
        round(random.uniform(0,10),2)
    ])

df = pd.DataFrame(alunos, columns=[
    'Nome','Idade', 'Endereço', 'Matrícula','Ano Escolar','Turma',
    'Média em Ciências da Natureza',
    'Média em Ciências Humanas',
    'Média em Matemática',
    'Média em Linguagens',
    'Média em Redação'
])

print(df.head())

#deletar os identificadores do dataframe
df2 = df.copy()
df2 = df2.drop(['Nome', 'Matrícula', 'Endereço'], axis=1)

#anonimizar quase identificadores

df2['Idade'] = pd.cut(df2['Idade'],bins=[13,16,19],labels=['14-16','17-19'])
df2['Média em Ciências da Natureza'] = pd.cut(df2['Média em Ciências da Natureza'],bins=[0,5,10.1],labels=['0-5','5-10'])
df2['Média em Ciências Humanas'] = pd.cut(df2['Média em Ciências Humanas'],bins=[0,5,10.1],labels=['0-5','5-10'])
df2['Média em Matemática'] = pd.cut(df2['Média em Matemática'],bins=[0,5,10.1],labels=['0-5','5-10'])
df2['Média em Linguagens'] = pd.cut(df2['Média em Linguagens'],bins=[0,5,10.1],labels=['0-5','5-10'])
df2['Média em Redação'] = pd.cut(df2['Média em Redação'],bins=[0,5,10.1],labels=['0-5','5-10'])
df2['Ano Escolar'] = 'Ensino Médio'
df2['Turma'] = '*'
print(df2.head())

k = df2.groupby(df2.columns.tolist(), observed=True).size().min()
print("Valor mínimo de k:", k)
# Out:
#                  Nome  Idade  \
# 0     Benício Martins     15
# 1      Luara da Rocha     14
# 2       Joana Sampaio     15
# 3         Lunna Lopes     17
# 4  Ana Sophia Barbosa     18
#
#                                             Endereço  Matrícula Ano Escolar  \
# 0  Alameda de Castro\nIpiranga\n75614-162 Mendes ...  939998198          3º
# 1  Viela Bento Moura\nSanta Cruz\n00076-616 Pasto...  835293592          3º
# 2  Passarela João Miguel Andrade, 298\nMaria Hele...  988499132          2º
# 3  Setor da Cunha, 925\nRenascença\n01274408 Nova...  886952042          1º
# 4  Colônia de Nascimento, 56\nNova America\n49152...  919918312          1º
#
#   Turma  Média em Ciências da Natureza  Média em Ciências Humanas  \
# 0     A                           3.84                       9.92
# 1     A                           6.23                       6.79
# 2     A                           9.90                       7.36
# 3     A                           4.14                       1.01
# 4     B                           5.59                       1.90
#
#    Média em Matemática  Média em Linguagens  Média em Redação
# 0                 6.82                 6.51              5.90
# 1                 3.02                 8.46              6.32
# 2                 3.72                 2.22              8.27
# 3                 9.17                 6.47              4.65
# 4                 8.17                 5.15              9.95
#    Idade   Ano Escolar Turma Média em Ciências da Natureza  \
# 0  14-16  Ensino Médio     *                           0-5
# 1  14-16  Ensino Médio     *                          5-10
# 2  14-16  Ensino Médio     *                          5-10
# 3  17-19  Ensino Médio     *                           0-5
# 4  17-19  Ensino Médio     *                          5-10
#
#   Média em Ciências Humanas Média em Matemática Média em Linguagens  \
# 0                      5-10                5-10                5-10
# 1                      5-10                 0-5                5-10
# 2                      5-10                 0-5                 0-5
# 3                       0-5                5-10                5-10
# 4                       0-5                5-10                5-10
#
#   Média em Redação
# 0             5-10
# 1             5-10
# 2             5-10
# 3              0-5
# 4             5-10
# Valor mínimo de k: 6
